# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ps_comp = pd.read_csv('ps_comp_data.csv')

# %% [markdown]
# #### Documentación de Planetary systems composite
#
# https://exoplanetarchive.ipac.caltech.edu/docs/API_PS_columns.html

# %% [markdown]
# Descripción de cada una de las columnas:
#
# - **planet_name:** Planet Name
# - **hostname:** Stellar name
# - **sys_num_stars:** Number of Stars
# - **sys_num_planet:** Number of Planets
# - **discovery_method:** Discovery Method
# - **discovery_year:** Discovery Year
# - **discovery_telescope:** Discovery Telescope
# - **orbital_period:** Orbital Period, unit=days
# - **orbital_semi_major:** Orbit Semi-Major Axis, unit = au
# - **planet_radius_earth:** Planet Radius (Earth Radius)
# - **planet_radius_jupiter:** Planet Radius (Jupiter Radius)
# - **planet_mass_earth:** Planet Mass (Earth Mass)
# - **planet_mass_jupiter:** Planet Mass (Jupiter Mass)
# - **eccentricity:** Eccentricity
# - **stellar_eff_temp:** Stellar Effective Temperature unit=K
# - **stellar_radius:** Stellar Radius (Solar Radius)
# - **stellar_mass:** Stellar Mass
# - **dist_system:** Distance, unit = pc

# %%
ps_comp.head()
# Out:
#              planet_name             hostname  sys_num_stars  sys_num_planet  \
# 0  OGLE-2016-BLG-1227L b  OGLE-2016-BLG-1227L              1               1
# 1               GJ 480 b               GJ 480              1               1
# 2           Kepler-276 c           Kepler-276              1               3
# 3           Kepler-829 b           Kepler-829              1               1
# 4               K2-283 b               K2-283              1               1
#
#   discovery_method  discovery_year                discovery_telescope  \
# 0     Microlensing            2020  1.3 m Warsaw University Telescope
# 1  Radial Velocity            2020                Multiple Telescopes
# 2          Transit            2013            0.95 m Kepler Telescope
# 3          Transit            2016            0.95 m Kepler Telescope
# 4          Transit            2018            0.95 m Kepler Telescope
#
#    orbital_period  orbital_semi_major  planet_radius_earth  \
# ...

# %% [markdown]
# ### Describiendo la data

# %%
ps_comp.shape
# Out:
# (4521, 19)

# %%
ps_comp.columns
# Out:
# Index(['planet_name', 'hostname', 'sys_num_stars', 'sys_num_planet',
#        'discovery_method', 'discovery_year', 'discovery_telescope',
#        'orbital_period', 'orbital_semi_major', 'planet_radius_earth',
#        'planet_radius_jupiter', 'planet_mass_earth', 'planet_mass_jupiter',
#        'eccentricity', 'stellar_eff_temp', 'stellar_radius', 'stellar_mass',
#        'dist_system', 'dist_system_ly'],
#       dtype='object')

# %%
ps_comp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4521 entries, 0 to 4520
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   planet_name            4521 non-null   object
#  1   hostname               4521 non-null   object
#  2   sys_num_stars          4521 non-null   int64
#  3   sys_num_planet         4521 non-null   int64
#  4   discovery_method       4521 non-null   object
#  5   discovery_year         4521 non-null   int64
#  6   discovery_telescope    4521 non-null   object
#  7   orbital_period         4370 non-null   float64
#  8   orbital_semi_major     4337 non-null   float64
#  9   planet_radius_earth    4507 non-null   float64
#  10  planet_radius_jupiter  4505 non-null   float64
#  11  planet_mass_earth      4499 non-null   float64
#  12  planet_mass_jupiter    4499 non-null   float64
#  13  eccentricity           3981 non-null   float64
# ...

# %%
ps_comp.isnull().sum()
# Out:
# planet_name                0
# hostname                   0
# sys_num_stars              0
# sys_num_planet             0
# discovery_method           0
# discovery_year             0
# discovery_telescope        0
# orbital_period           151
# orbital_semi_major       184
# planet_radius_earth       14
# planet_radius_jupiter     16
# planet_mass_earth         22
# planet_mass_jupiter       22
# eccentricity             540
# stellar_eff_temp         122
# stellar_radius           141
# stellar_mass               4
# dist_system                6
# dist_system_ly             6
# dtype: int64

# %%
ps_null = ps_comp.isnull().sum()

# %%
ps_null[ps_null > 0]
# Out:
# orbital_period           151
# orbital_semi_major       184
# planet_radius_earth       14
# planet_radius_jupiter     16
# planet_mass_earth         22
# planet_mass_jupiter       22
# eccentricity             540
# stellar_eff_temp         122
# stellar_radius           141
# stellar_mass               4
# dist_system                6
# dist_system_ly             6
# dtype: int64

# %%
ps_null_mean = ps_comp.isnull().mean()

# %%
ps_null_mean[ps_null_mean > 0.000000]
# Out:
# orbital_period           0.033400
# orbital_semi_major       0.040699
# planet_radius_earth      0.003097
# planet_radius_jupiter    0.003539
# planet_mass_earth        0.004866
# planet_mass_jupiter      0.004866
# eccentricity             0.119443
# stellar_eff_temp         0.026985
# stellar_radius           0.031188
# stellar_mass             0.000885
# dist_system              0.001327
# dist_system_ly           0.001327
# dtype: float64

# %%
ps_comp.describe()
# Out:
#        sys_num_stars  sys_num_planet  discovery_year  orbital_period  \
# count    4521.000000     4521.000000     4521.000000    4.370000e+03
# mean        1.110816        1.788764     2014.790754    9.584998e+04
# std         0.353078        1.170174        3.928567    6.083305e+06
# min         1.000000        1.000000     1989.000000    9.070629e-02
# 25%         1.000000        1.000000     2014.000000    4.458856e+00
# 50%         1.000000        1.000000     2016.000000    1.181235e+01
# 75%         1.000000        2.000000     2016.000000    4.169794e+01
# max         4.000000        8.000000     2021.000000    4.020000e+08
#
#        orbital_semi_major  planet_radius_earth  planet_radius_jupiter  \
# count         4337.000000          4507.000000            4505.000000
# mean             7.134733             5.706612               0.509390
# std            145.850723             5.394579               0.481389
# ...

# %%
correlation = ps_comp.corr()

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 12)})
sns.heatmap(correlation, annot=True, )

plt.savefig('heatmap.png', transparent=True)

# %% [markdown]
# Claramente existe una relación entre orbital_period (periodo orbital) y el orbital_semi_major (semi eje mayor)

# %% [markdown]
# ### Revisando valores duplicados

# %%
ps_comp['planet_name'].value_counts()
# Out:
# Kepler-179 b    1
# K2-29 b         1
# WASP-75 b       1
# Kepler-141 b    1
# NY Vir b        1
#                ..
# K2-254 b        1
# Kepler-522 b    1
# K2-193 b        1
# Kepler-79 e     1
# K2-36 c         1
# Name: planet_name, Length: 4521, dtype: int64

# %% [markdown]
# ###  Transformando las columnas orbital_period de días a horas y de días a años

# %%
ps_comp['orbital_period_h'] = ps_comp['orbital_period'] * 24

# %%
ps_comp['orbital_period_y'] = (ps_comp['orbital_period']) / 365

# %% [markdown]
# ### Estudiando la data a traves de visualización

# %% [markdown]
# #### Número de planetas por metodo de descubrimiento

# %%
ps_comp()

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 10)})
ax = sns.countplot(x='discovery_method', data=ps_comp)

ax.set_title('Número de planetas por método de descubrimiento', fontsize=30)
ax.set(xlabel=None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=55, size=15);
plt.savefig('num_planets.png')

# %% [markdown]
# ### Planetas orbitando cuatro estrellas

# %%
ps_comp[ps_comp['sys_num_stars'] == 4]
# Out:
#      planet_name  hostname  sys_num_stars  sys_num_planet discovery_method  \
# 200   30 Ari B b  30 Ari B              4               1  Radial Velocity
# 3179       PH1 b       PH1              4               1          Transit
#
#       discovery_year            discovery_telescope  orbital_period  \
# 200             2009  2.0 m Alfred Jensch Telescope       335.10001
# 3179            2012        0.95 m Kepler Telescope       138.31700
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 200                0.990                12.30  ...          4392.4106
# 3179               0.652                 6.18  ...           169.0000
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 200                13.820        0.2900            6331.0            1.41
# 3179                0.531        0.0702            6407.0            1.73
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# ...

# %% [markdown]
# ### Trappist

# %%
ps_comp_trappist = ps_comp[ps_comp['sys_num_planet'] == 7]
ps_comp_trappist
# Out:
#        planet_name    hostname  sys_num_stars  sys_num_planet  \
# 294   TRAPPIST-1 h  TRAPPIST-1              1               7
# 1533  TRAPPIST-1 b  TRAPPIST-1              1               7
# 2597  TRAPPIST-1 g  TRAPPIST-1              1               7
# 2605  TRAPPIST-1 c  TRAPPIST-1              1               7
# 3474  TRAPPIST-1 f  TRAPPIST-1              1               7
# 3690  TRAPPIST-1 e  TRAPPIST-1              1               7
# 3735  TRAPPIST-1 d  TRAPPIST-1              1               7
#
#      discovery_method  discovery_year  \
# 294           Transit            2017
# 1533          Transit            2016
# 2597          Transit            2017
# 2605          Transit            2016
# 3474          Transit            2017
# 3690          Transit            2017
# 3735          Transit            2016
#
#                                     discovery_telescope  orbital_period  \
# 294                                 Multiple Telescopes       18.772866
# ...

# %%
ps_comp_trappist.to_excel('Trappist.xlsx')

# %%
ps_comp_KOI = ps_comp[ps_comp['sys_num_planet'] == 8]
ps_comp_KOI
# Out:
#       planet_name hostname  sys_num_stars  sys_num_planet discovery_method  \
# 802     KOI-351 d  KOI-351              1               8          Transit
# 1427  Kepler-90 i  KOI-351              1               8          Transit
# 2058    KOI-351 c  KOI-351              1               8          Transit
# 2059    KOI-351 e  KOI-351              1               8          Transit
# 2880    KOI-351 h  KOI-351              1               8          Transit
# 3215    KOI-351 b  KOI-351              1               8          Transit
# 4050    KOI-351 g  KOI-351              1               8          Transit
# 4413    KOI-351 f  KOI-351              1               8          Transit
#
#       discovery_year      discovery_telescope  orbital_period  \
# 802             2013  0.95 m Kepler Telescope       59.736670
# 1427            2017  0.95 m Kepler Telescope       14.449120
# 2058            2013  0.95 m Kepler Telescope        8.719375
# ...

# %%
ps_comp_KOI.to_excel('KOI.xlsx')

# %% [markdown]
# Crea Grafico de planet mass vs orbital period para los sistemas planetarios

# %% [markdown]
# ### Número de estrellas en el sistema

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 10)})
ax = sns.countplot(x='sys_num_stars', data=ps_comp)

ax.set_title('Número de estrellas en el sistema', fontsize=30)
ax.set(xlabel=None)
ax.set_xticklabels(ax.get_xticklabels(), size=15);

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 10)})
ax = sns.countplot(x='sys_num_planet', data=ps_comp)

ax.set_title('Número de planetas en el sistema', fontsize=30)
ax.set(xlabel=None)
ax.set_xticklabels(ax.get_xticklabels(), size=15);

# %% [markdown]
# ### Número de planetas por año de descubrimiento

# %%
ps_comp['discovery_year'].unique()
# Out:
# array([2020, 2013, 2016, 2018, 2010, 2005, 2007, 2008, 2012, 2015, 2017,
#        2019, 2014, 2009, 1996, 2011, 2021, 2000, 2004, 1999, 2006, 2001,
#        2002, 2003, 1998, 1992, 1995, 1997, 1994, 1989], dtype=int64)

# %%
years = list(ps_comp['discovery_year'].unique())
years
# Out:
# [2020,
#  2013,
#  2016,
#  2018,
#  2010,
#  2005,
#  2007,
#  2008,
#  2012,
#  2015,
#  2017,
#  2019,
#  2014,
#  2009,
#  1996,
#  2011,
#  2021,
#  2000,
#  2004,
#  1999,
#  2006,
#  2001,
#  2002,
#  2003,
#  1998,
#  1992,
#  1995,
#  1997,
#  1994,
#  1989]

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (20, 10)})
ax = sns.lineplot(data=ps_comp['discovery_year'].value_counts())
ax.set_title('Numeros de Descubrimientos por Año', fontsize=30)
ax.set_xticks(years)
ax.set_xticklabels(years, rotation=55, size=15)
ax.set(ylabel=None);

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 10)})


ax = sns.scatterplot(x='orbital_period', y='planet_mass_earth', size='planet_radius_jupiter',  data=ps_comp, 
                     hue='discovery_method', alpha=0.7)

ax.set_xscale('log')
ax.set_yscale('log')

# %% [markdown]
# **El de mayor radio en radio de jupiter**

# %%
ps_comp.sort_values('planet_radius_jupiter', ascending=False).head(1)
# Out:
#       planet_name   hostname  sys_num_stars  sys_num_planet discovery_method  \
# 2798  HD 100546 b  HD 100546              1               1          Imaging
#
#       discovery_year                discovery_telescope  orbital_period  \
# 2798            2014  8.2 m ESO VLT UT4 Yepun Telescope             NaN
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 2798                53.0               77.342  ...           239000.0
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 2798                752.0           NaN           10500.0            1.85
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# 2798           2.4      109.677      357.766374               NaN
#
#       orbital_period_y
# 2798               NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de menor radio en radio en radio de jupiter**

# %%
ps_comp.sort_values('planet_radius_jupiter').head(1)
# Out:
#       planet_name   hostname  sys_num_stars  sys_num_planet discovery_method  \
# 4169  Kepler-37 b  Kepler-37              1               4          Transit
#
#       discovery_year      discovery_telescope  orbital_period  \
# 4169            2013  0.95 m Kepler Telescope        13.36731
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 4169              0.1003                0.296  ...             3.1783
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 4169                 0.01           0.0            5417.0            0.79
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# 4169          0.87      63.9207      208.509323         320.81544
#
#       orbital_period_y
# 4169          0.036623
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de mayor radio en radio terrestre**

# %%
ps_comp.sort_values('planet_radius_earth', ascending=False).head(1)
# Out:
#       planet_name   hostname  sys_num_stars  sys_num_planet discovery_method  \
# 2798  HD 100546 b  HD 100546              1               1          Imaging
#
#       discovery_year                discovery_telescope  orbital_period  \
# 2798            2014  8.2 m ESO VLT UT4 Yepun Telescope             NaN
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 2798                53.0               77.342  ...           239000.0
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 2798                752.0           NaN           10500.0            1.85
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# 2798           2.4      109.677      357.766374               NaN
#
#       orbital_period_y
# 2798               NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de menor radio en radio Terrestre**

# %%
ps_comp.sort_values('planet_radius_earth').head(1)
# Out:
#       planet_name   hostname  sys_num_stars  sys_num_planet discovery_method  \
# 4169  Kepler-37 b  Kepler-37              1               4          Transit
#
#       discovery_year      discovery_telescope  orbital_period  \
# 4169            2013  0.95 m Kepler Telescope        13.36731
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 4169              0.1003                0.296  ...             3.1783
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 4169                 0.01           0.0            5417.0            0.79
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# 4169          0.87      63.9207      208.509323         320.81544
#
#       orbital_period_y
# 4169          0.036623
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de mayor periodo orbital**

# %%
ps_comp.sort_values('orbital_period', ascending=False).head(1)
# Out:
#        planet_name      hostname  sys_num_stars  sys_num_planet  \
# 3489  COCONUTS-2 b  COCONUTS-2 A              1               1
#
#      discovery_method  discovery_year discovery_telescope  orbital_period  \
# 3489          Imaging            2021     3.2 m telescope     402000000.0
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 3489              7506.0               12.442  ...         2002.31896
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 3489                  6.3           NaN            3406.0            0.39
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# 3489          0.37      10.8864       35.511437      9.648000e+09
#
#       orbital_period_y
# 3489      1.101370e+06
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de mayor periodo orbital**

# %%
ps_comp.sort_values('orbital_period').head(1)
# Out:
#            planet_name        hostname  sys_num_stars  sys_num_planet  \
# 4162  PSR J1719-1438 b  PSR J1719-1438              1               1
#
#      discovery_method  discovery_year          discovery_telescope  \
# 4162    Pulsar Timing            2011  64 m Parkes Radio Telescope
#
#       orbital_period  orbital_semi_major  planet_radius_earth  ...  \
# 4162        0.090706              0.0044                  NaN  ...
#
#       planet_mass_earth  planet_mass_jupiter  eccentricity  stellar_eff_temp  \
# 4162              382.8                  1.2          0.06            4500.0
#
#       stellar_radius  stellar_mass  dist_system  dist_system_ly  \
# 4162             NaN           1.4       1200.0          3914.4
#
#       orbital_period_h  orbital_period_y
# 4162          2.176951          0.000249
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de mayor masa en masas de jupiter**

# %%
ps_comp.sort_values('planet_mass_jupiter', ascending=False).head(1)
# Out:
#       planet_name   hostname  sys_num_stars  sys_num_planet discovery_method  \
# 2798  HD 100546 b  HD 100546              1               1          Imaging
#
#       discovery_year                discovery_telescope  orbital_period  \
# 2798            2014  8.2 m ESO VLT UT4 Yepun Telescope             NaN
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 2798                53.0               77.342  ...           239000.0
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 2798                752.0           NaN           10500.0            1.85
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# 2798           2.4      109.677      357.766374               NaN
#
#       orbital_period_y
# 2798               NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de menor masa en masas de jupiter**

# %%
ps_comp.sort_values('planet_mass_jupiter').head(1)
# Out:
#          planet_name      hostname  sys_num_stars  sys_num_planet  \
# 3601  PSR B1257+12 b  PSR B1257+12              1               3
#
#      discovery_method  discovery_year            discovery_telescope  \
# 3601    Pulsar Timing            1994  305 m Arecibo Radio Telescope
#
#       orbital_period  orbital_semi_major  planet_radius_earth  ...  \
# 3601          25.262                0.19                0.338  ...
#
#       planet_mass_earth  planet_mass_jupiter  eccentricity  stellar_eff_temp  \
# 3601               0.02              0.00006           0.0               NaN
#
#       stellar_radius  stellar_mass  dist_system  dist_system_ly  \
# 3601             NaN           1.4        600.0          1957.2
#
#       orbital_period_h  orbital_period_y
# 3601           606.288          0.069211
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de mayor masa en masas terrestres**

# %%
ps_comp.sort_values('planet_mass_earth', ascending=False).head(1)
# Out:
#       planet_name   hostname  sys_num_stars  sys_num_planet discovery_method  \
# 2798  HD 100546 b  HD 100546              1               1          Imaging
#
#       discovery_year                discovery_telescope  orbital_period  \
# 2798            2014  8.2 m ESO VLT UT4 Yepun Telescope             NaN
#
#       orbital_semi_major  planet_radius_earth  ...  planet_mass_earth  \
# 2798                53.0               77.342  ...           239000.0
#
#       planet_mass_jupiter  eccentricity  stellar_eff_temp  stellar_radius  \
# 2798                752.0           NaN           10500.0            1.85
#
#       stellar_mass  dist_system  dist_system_ly  orbital_period_h  \
# 2798           2.4      109.677      357.766374               NaN
#
#       orbital_period_y
# 2798               NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# **El de menor masa en masas terrestres**

# %%
ps_comp.sort_values('planet_mass_earth').head(1)
# Out:
#          planet_name      hostname  sys_num_stars  sys_num_planet  \
# 3601  PSR B1257+12 b  PSR B1257+12              1               3
#
#      discovery_method  discovery_year            discovery_telescope  \
# 3601    Pulsar Timing            1994  305 m Arecibo Radio Telescope
#
#       orbital_period  orbital_semi_major  planet_radius_earth  ...  \
# 3601          25.262                0.19                0.338  ...
#
#       planet_mass_earth  planet_mass_jupiter  eccentricity  stellar_eff_temp  \
# 3601               0.02              0.00006           0.0               NaN
#
#       stellar_radius  stellar_mass  dist_system  dist_system_ly  \
# 3601             NaN           1.4        600.0          1957.2
#
#       orbital_period_h  orbital_period_y
# 3601           606.288          0.069211
#
# [1 rows x 21 columns]

# %%
ps_comp.to_excel('ps_comp.xlsx')

# %% [markdown]
# ## Orbital period vs orbital semi major

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 10)})


ax = sns.scatterplot(x='orbital_period', y='orbital_semi_major', size='planet_radius_jupiter', data=ps_comp, 
                     hue='discovery_method', alpha=0.6)

ax.set_xscale('log')
ax.set_yscale('log')

# %%
sns.histplot(ps_comp['planet_radius_jupiter'])
# Out:
# <AxesSubplot:xlabel='planet_radius_jupiter', ylabel='Count'>

# %% [markdown]
# ### Filtrado

# %%
ps_comp_copy = ps_comp.copy()

# %%
ps_comp_copy
# Out:
#                 planet_name             hostname  sys_num_stars  \
# 0     OGLE-2016-BLG-1227L b  OGLE-2016-BLG-1227L              1
# 1                  GJ 480 b               GJ 480              1
# 2              Kepler-276 c           Kepler-276              1
# 3              Kepler-829 b           Kepler-829              1
# 4                  K2-283 b               K2-283              1
# ...                     ...                  ...            ...
# 4516               K2-357 b               K2-357              1
# 4517               K2-356 b               K2-356              1
# 4518               K2-355 b               K2-355              1
# 4519             TOI-1518 b             TOI-1518              1
# 4520        TIC 172900988 b     TIC 172900988 Aa              2
#
#       sys_num_planet discovery_method  discovery_year  \
# 0                  1     Microlensing            2020
# 1                  1  Radial Velocity            2020
# ...

# %%
ps_comp_copy = ps_comp_copy.loc[ps_comp_copy['orbital_period'] < 1000000]

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 10)})


ax = sns.scatterplot(x='orbital_period', y='orbital_semi_major', size='planet_radius_jupiter', data=ps_comp_copy, 
                     hue='discovery_method', alpha=0.6)

ax.set_xscale('log')
ax.set_yscale('log')

# %%
sns.set(context='paper', style='darkgrid', rc={'figure.figsize': (15, 10)})


ax = sns.scatterplot(x='orbital_period', y='planet_mass_earth', size='planet_radius_jupiter',  data=ps_comp_copy, 
                     hue='discovery_method', alpha=0.7)

ax.set_xscale('log')
ax.set_yscale('log')

# %%
ps_comp_copy = ps_comp_copy.loc[ps_comp_copy['planet_radius_jupiter'] < 2.5]

# %%
sns.histplot(ps_comp_copy['planet_radius_jupiter'])
# Out:
# <AxesSubplot:xlabel='planet_radius_jupiter', ylabel='Count'>
